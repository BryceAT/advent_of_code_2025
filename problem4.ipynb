# %%
import advent_of_code_2025
grid = advent_of_code_2025.get_map_char_py(4,False,1)

# %%
grid
# Out:
# [['.', '.', '@', '@', '.', '@', '@', '@', '@', '.'],
#  ['@', '@', '@', '.', '@', '.', '@', '.', '@', '@'],
#  ['@', '@', '@', '@', '@', '.', '@', '.', '@', '@'],
#  ['@', '.', '@', '@', '@', '@', '.', '.', '@', '.'],
#  ['@', '@', '.', '@', '@', '@', '@', '.', '@', '@'],
#  ['.', '@', '@', '@', '@', '@', '@', '@', '.', '@'],
#  ['.', '@', '.', '@', '.', '@', '.', '@', '@', '@'],
#  ['@', '.', '@', '@', '@', '.', '@', '@', '@', '@'],
#  ['.', '@', '@', '@', '@', '@', '@', '@', '@', '.'],
#  ['@', '.', '@', '.', '@', '@', '@', '.', '@', '.']]

# %%
g = advent_of_code_2025.CharGrid(grid)

# %%
len([(x,y) for x in range(len(grid)) for y in range(len(grid[0])) if grid[x][y] == '@' and g.count_neighbors(x,y) < 4])
# Out:
# 1457

# %%
tot = 0
while (can_be_removed := [(x,y) for x in range(len(grid)) for y in range(len(grid[0])) if grid[x][y] == '@' and g.count_neighbors(x,y) < 4]):
    for x,y in can_be_removed:
        grid[x][y] = '.'
    g = advent_of_code_2025.CharGrid(grid)
    tot += len(can_be_removed)
tot
# Out:
# 8310
